# %%
from ds_utils.ds_preamble import *
from ds_utils.ds_plotting import *
from ds_utils.ds_helper import *
import datetime
import duckdb
# Out:
# calling ds_preamble..
# calling ds_helper...

# %%
df1 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df1.rename({0:'id'}, axis=1, inplace=True)

df2 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df2.rename({0:'id'}, axis=1, inplace=True)

# df1
# df2
# df1.merge(df2, on='id').sort_values(by='id')

# M1
pd.concat([df1.id,df2.id]).drop_duplicates().sort_values().reset_index(drop=True)

len(set(df1.id).union(set(df2.id)))
# Out:
#     id   1   2   3   4   5   6   7   8   9
# 0   16  55  48  92  63  14  83  13  88   9
# 1   93   5  16  70  21  67  20  36  76  46
# 2   61  22  86  43  77  56  45  86  70  18
# 3   94  31  43  88  84  25  51  22  17  57
# 4   51  60  69  33  96  85  80  42  67  23
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 95  53  48   6  52  75  57  23  28  35   6
# 96  88  12  76  88  35  14  58  95  79  43
# 97  41  52  20  99   4  69  74  57  36  43
# 98  33  73  77  12  20  18  98  31  77  79
# 99  13  80   5  84  32  96  14  59  76  80
#
# [100 rows x 10 columns]
#     id   1   2   3   4   5   6   7   8   9
# 0   41  41  48  51  52  30   5  48  34  64
# 1   11  28  99  61  56  30  92  69   5  83
# 2   83  19  96  23  79  58  55  82  14  62
# 3   67   9  11  24  85  80  56  74  21  41
# 4   34   4  74  68  63  60  59  60  38  28
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 95  14  70  68  62  27  91  54  54  36  99
# 96  10  89  62  44   7  58  51  15  34  53
# 97  69  51  50  22  36  86  70  13  53  24
# 98  51  33  18  35  32  86  53  38  41  63
# 99  46  44  60  31  99  83   1  78  74   4
#
# [100 rows x 10 columns]
# 82

# %%
df1['id'].nunique()
df2['id'].nunique()
len(set(df1['id']).union(df2['id']))
# Out:
# 61
# 62
# 82

# %%
purchase=pd.DataFrame(dict(sid=[1,1,2,2,3,4,5,9], purchase=[10,20,2,3,1,2,4,44]))
students = pd.DataFrame(dict(sid=[1,2,3,4,5,6,7], age=[10,22,11,21,55,19,23]))
print(purchase)
print(students)
print(purchase.merge(students, on='sid', how='inner'))
print(purchase.merge(students, on='sid', how='outer'))
print(purchase.merge(students, on='sid', how='left'))
print(purchase.merge(students, on='sid', how='right'))
# Out:
#    sid  purchase
# 0    1        10
# 1    1        20
# 2    2         2
# 3    2         3
# 4    3         1
# 5    4         2
# 6    5         4
# 7    9        44
#    sid  age
# 0    1   10
# 1    2   22
# 2    3   11
# 3    4   21
# 4    5   55
# 5    6   19
# 6    7   23
#    sid  purchase  age
# 0    1        10   10
# 1    1        20   10
# 2    2         2   22
# 3    2         3   22
# 4    3         1   11
# 5    4         2   21
# 6    5         4   55
#    sid  purchase   age
# 0    1      10.0  10.0
# 1    1      20.0  10.0
# 2    2       2.0  22.0
# 3    2       3.0  22.0
# 4    3       1.0  11.0
# 5    4       2.0  21.0
# 6    5       4.0  55.0
# 7    9      44.0   NaN
# 8    6       NaN  19.0
# 9    7       NaN  23.0
#    sid  purchase   age
# 0    1        10  10.0
# 1    1        20  10.0
# 2    2         2  22.0
# 3    2         3  22.0
# 4    3         1  11.0
# 5    4         2  21.0
# 6    5         4  55.0
# 7    9        44   NaN
#    sid  purchase  age
# 0    1      10.0   10
# 1    1      20.0   10
# 2    2       2.0   22
# 3    2       3.0   22
# 4    3       1.0   11
# 5    4       2.0   21
# 6    5       4.0   55
# 7    6       NaN   19
# 8    7       NaN   23

# %%
s1=pd.Series([1,2,3,4],index=[5,6,7,8,])
s2=pd.Series([1,2,3,4],index=[1,2,3,4])
s3=pd.Series([1,2,3,4,5,6],index=[6,6,5,5,7,8])
print(pd.concat([s1,s2], axis=1))
#      0    1
# 5  1.0  NaN
# 6  2.0  NaN
# 7  3.0  NaN
# 8  4.0  NaN
# 1  NaN  1.0
# 2  NaN  2.0
# 3  NaN  3.0
# 4  NaN  4.0
print(pd.concat([s3,s1], axis=1))
#    0  1
# 6  1  2
# 6  2  2
# 5  3  1
# 5  4  1
# 7  5  3
# 8  6  4
# Out:
#      0    1
# 5  1.0  NaN
# 6  2.0  NaN
# 7  3.0  NaN
# 8  4.0  NaN
# 1  NaN  1.0
# 2  NaN  2.0
# 3  NaN  3.0
# 4  NaN  4.0
#    0  1
# 6  1  2
# 6  2  2
# 5  3  1
# 5  4  1
# 7  5  3
# 8  6  4

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])
pd.merge(s1,s2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_81433/1365286748.py in <module>
#       2 s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
#       3 s3 = pd.Series([5, 6], index=['f', 'g'])
# ----> 4 pd.merge(s1,s2)
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     626         validate: str | None = None,
#     627     ):
# --> 628         _left = _validate_operand(left)
#     629         _right = _validate_operand(right)
#     630         self.left = self.orig_left = _left
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _validate_operand(obj)
#    2275     elif isinstance(obj, ABCSeries):
#    2276         if obj.name is None:
# -> 2277             raise ValueError("Cannot merge a Series without a name")
#    2278         else:
#    2279             return obj.to_frame()
#
# ValueError: Cannot merge a Series without a name

# %%
player_list = [['M.S.Dhoni', 36, 75, 5428000],
               ['A.B.D Villers', 38, 74, 3428000],
               ['V.Kholi', 31, 70, 8428000],
               ['S.Smith', 34, 80, 4428000],
               ['C.Gayle', 40, 100, 4528000],
               ['J.Root', 33, 72, 7028000],
               ['K.Peterson', 42, 85, 2528000]]
df = pd.DataFrame(player_list, 
                  columns = ['Name', 'Age', 
                             'Weight', 'Salary'])
df1, df2 = [gp for _, gp in df.groupby(df.Age<35)]
df1
df2
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 4        C.Gayle   40     100  4528000
# 6     K.Peterson   42      85  2528000
#       Name  Age  Weight   Salary
# 2  V.Kholi   31      70  8428000
# 3  S.Smith   34      80  4428000
# 5   J.Root   33      72  7028000

# %%
df.isna().sum().sum()
# Out:
# 0
