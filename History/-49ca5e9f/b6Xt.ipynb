# %%
from ds_utils.ds_preamble import *
from ds_utils.ds_plotting import *
from ds_utils.ds_helper import *
import datetime
import duckdb

# %%
path = r'/Users/whlin/Library/CloudStorage/OneDrive-HKUSTConnect/Academic/Notes of HKCC/HKCC Teaching/SEHH2239/AR/SEHH2239 AR 201_all_class.xlsx'
df = pd.read_excel(path, sheet_name='score_all', usecols='A:F')
df
# df.groupby('Group').agg(['mean','median','max'])

# sns.barplot(data=df, x='')

df_melt = df.melt(id_vars=['Group', 'Department'], value_vars=['mid','a1','a2'], var_name='asm', value_name='score')

df_melt

sns.catplot(data=df_melt, x='asm', y='score', hue='Group', estimator=np.median, kind='bar', ci=None).set(title='SEHH2239-22S2', xlabel='assessment', ylabel='median')

# sns.catplot(data=df.melt(id_vars=['Group', 'Department'], value_vars=['mid','a1','a2']), x='variable',y='value', hue='Department', estimator=np.median, kind='bar', ci=None).set(title='SEHH2239-22S2', xlabel='assessment', ylabel='median')

# sns.displot(data=df_melt, x='score',col='asm',kind='hist')
sns.displot(data=df_melt, x='score', col='asm', col_wrap=3, kind='hist', stat='density', kde=True, element='step', bins=15)


sns.catplot(data=df_melt, x='asm', y='score', hue='Department', kind='box', aspect=2.5)
sns.catplot(data=df_melt, x='asm', y='score', hue='Group', kind='box', aspect=2.5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_96591/2232542433.py in <module>
#       1 path = r'/Users/whlin/Library/CloudStorage/OneDrive-HKUSTConnect/Academic/Notes of HKCC/HKCC Teaching/SEHH2239/AR/SEHH2239 AR Template with Exam 201.xlsx'
# ----> 2 df = pd.read_excel(path, sheet_name='score_all', usecols='A:F')
#       3 df
#       4 # df.groupby('Group').agg(['mean','median','max'])
#       5
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1374                 ext = "xls"
#    1375             else:
# -> 1376                 ext = inspect_excel_format(
#    1377                     content_or_path=path_or_buffer, storage_options=storage_options
#    1378                 )
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1248         content_or_path = BytesIO(content_or_path)
#    1249
# -> 1250     with get_handle(
#    1251         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252     ) as handle:
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     796         else:
#     797             # Binary mode
# --> 798             handle = open(handle, ioargs.mode)
#     799         handles.append(handle)
#     800
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/whlin/Library/CloudStorage/OneDrive-HKUSTConnect/Academic/Notes of HKCC/HKCC Teaching/SEHH2239/AR/SEHH2239 AR Template with Exam 201.xlsx'

# %%
# Out:
# /Users/whlin/miniforge3/envs/data_science/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/whlin/miniforge3/envs/data_science/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='asm', ylabel='score'>

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.drop('Group',axis=1).corr(), annot=True,cmap="Blues")
plt.title("correlation")
# Out:
# <AxesSubplot:>
# Text(0.5, 1.0, 'correlation')

# %%
# sns.pairplot(df, hue='program', diag_kind="hist", corner=True)
# sns.pairplot(df, hue='program', diag_kind="kde", corner=True)
sns.pairplot(df.drop('Group',axis=1), diag_kind="kde", corner=True, aspect=1.5)

# %%
sns.countplot(data=df, x='Group', hue='Department')

print(df.groupby('Department').Group.agg(['size']))
# Out:
# <AxesSubplot:xlabel='Group', ylabel='count'>
#             size
# Department
# 8C112-AS       4
# 8C112-IT     247
# 8C112-SDS     14
