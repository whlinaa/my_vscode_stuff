# %%
from ds_preamble import *

# %%
df1 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df1.rename({0:'id'}, axis=1, inplace=True)

df2 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df2.rename({0:'id'}, axis=1, inplace=True)

# df1
# df2
df1.merge(df2, on='id')



# pd.concat([df1.id,df2.id]).drop_duplicates().sort_values().reset_index(drop=True)

len(set(df1.id).union(set(df2.id)))
# Out:
#      id  1_x  2_x  3_x  4_x  5_x  6_x  7_x  8_x  9_x  1_y  2_y  3_y  4_y  5_y  \
# 0    47   92   23   84   99   72   63    2   38   65   96   94   12   88   59
# 1    47   92   23   84   99   72   63    2   38   65    3   17   17   37   89
# 2    47   92   23   84   99   72   63    2   38   65   78   34   75   17   13
# 3    47   34    4   70   93   25   29   83   95   66   96   94   12   88   59
# 4    47   34    4   70   93   25   29   83   95   66    3   17   17   37   89
# ..   ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 100  42   85   59   27   17   15   15   80   49   26    2   44   76    7   54
# 101  42   85   59   27   17   15   15   80   49   26   74   31   40   59   84
# 102  79   16   84   98   97   54   48   90   79   61   56   45    7   36    6
# 103  79   16   84   98   97   54   48   90   79   61   70   96   25   43   81
# 104  16   60   74   16   46    5   85   18   58   53   48   81    8   69   24
#
#      6_y  7_y  8_y  9_y
# 0     98   57   43   84
# 1     52   32   21   49
# 2     77   28   28   34
# 3     98   57   43   84
# 4     52   32   21   49
# ..   ...  ...  ...  ...
# 100   44   20   11   87
# 101   92   68   62   64
# 102   82   53   70   76
# 103   79   77   20    5
# 104   80   19   57   44
#
# [105 rows x 19 columns]
# 84

# %%
purchase=pd.DataFrame(dict(sid=[1,1,2,2,3,4,5,9], purchase=[10,20,2,3,1,2,4,44]))
students = pd.DataFrame(dict(sid=[1,2,3,4,5,6,7], age=[10,22,11,21,55,19,23]))
print(purchase)
print(students)
print(purchase.merge(students, on='sid', how='inner'))
print(purchase.merge(students, on='sid', how='outer'))
print(purchase.merge(students, on='sid', how='left'))
print(purchase.merge(students, on='sid', how='right'))
# Out:
#    sid  purchase
# 0    1        10
# 1    1        20
# 2    2         2
# 3    2         3
# 4    3         1
# 5    4         2
# 6    5         4
# 7    9        44
#    sid  age
# 0    1   10
# 1    2   22
# 2    3   11
# 3    4   21
# 4    5   55
# 5    6   19
# 6    7   23
#    sid  purchase  age
# 0    1        10   10
# 1    1        20   10
# 2    2         2   22
# 3    2         3   22
# 4    3         1   11
# 5    4         2   21
# 6    5         4   55
#    sid  purchase   age
# 0    1      10.0  10.0
# 1    1      20.0  10.0
# 2    2       2.0  22.0
# 3    2       3.0  22.0
# 4    3       1.0  11.0
# 5    4       2.0  21.0
# 6    5       4.0  55.0
# 7    9      44.0   NaN
# 8    6       NaN  19.0
# 9    7       NaN  23.0
#    sid  purchase   age
# 0    1        10  10.0
# 1    1        20  10.0
# 2    2         2  22.0
# 3    2         3  22.0
# 4    3         1  11.0
# 5    4         2  21.0
# 6    5         4  55.0
# 7    9        44   NaN
#    sid  purchase  age
# 0    1      10.0   10
# 1    1      20.0   10
# 2    2       2.0   22
# 3    2       3.0   22
# 4    3       1.0   11
# 5    4       2.0   21
# 6    5       4.0   55
# 7    6       NaN   19
# 8    7       NaN   23
