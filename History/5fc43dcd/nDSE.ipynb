# %%
from ds_preamble import *

# %%
df1 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df1.rename({0:'id'}, axis=1, inplace=True)

df2 = pd.DataFrame(np.random.randint(1,100, size=(100,10)))
df2.rename({0:'id'}, axis=1, inplace=True)

# df1
# df2
# df1.merge(df2, on='id').sort_values(by='id')



# pd.concat([df1.id,df2.id]).drop_duplicates().sort_values().reset_index(drop=True)

len(set(df1.id).union(set(df2.id)))
# Out:
#     id  1_x  2_x  3_x  4_x  5_x  6_x  7_x  8_x  9_x  1_y  2_y  3_y  4_y  5_y  \
# 90   3   24   38   32   41   14    8   34   39   66   86   71    4   63   39
# 0    4   91   74   52   77   78   94   68   79   89   73   18   28   80   27
# 71  12    2   41   49   95   45   72   76   33   62   62   22   34   98   94
# 72  12    2   41   49   95   45   72   76   33   62   24   22   91   22   64
# 79  13   33   39   74   86   79   66   26    5   38   67   35   75   58   10
# ..  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 32  97   91   41   71   32   93   52   73   99   68   89   29    5   79   65
# 33  97   91   41   71   32   93   52   73   99   68   47   89   63   16   99
# 31  97   73   82   83   20   26   61   49   53   71   47   89   63   16   99
# 9   99   56   24   38   42   56   50   10   65   23   82   39   34   75   82
# 8   99   57   54   13   35    4   35   36   83   62   82   39   34   75   82
#
#     6_y  7_y  8_y  9_y
# 90    6   99   82   69
# 0    43   84   51    4
# 71   17   77   27   58
# 72   53   26   37   15
# 79   58   60    9   85
# ..  ...  ...  ...  ...
# 32   96   92   45   81
# 33   42   78   43   99
# 31   42   78   43   99
# 9    72   25   47   45
# 8    72   25   47   45
#
# [102 rows x 19 columns]
# 84

# %%
purchase=pd.DataFrame(dict(sid=[1,1,2,2,3,4,5,9], purchase=[10,20,2,3,1,2,4,44]))
students = pd.DataFrame(dict(sid=[1,2,3,4,5,6,7], age=[10,22,11,21,55,19,23]))
print(purchase)
print(students)
print(purchase.merge(students, on='sid', how='inner'))
print(purchase.merge(students, on='sid', how='outer'))
print(purchase.merge(students, on='sid', how='left'))
print(purchase.merge(students, on='sid', how='right'))
# Out:
#    sid  purchase
# 0    1        10
# 1    1        20
# 2    2         2
# 3    2         3
# 4    3         1
# 5    4         2
# 6    5         4
# 7    9        44
#    sid  age
# 0    1   10
# 1    2   22
# 2    3   11
# 3    4   21
# 4    5   55
# 5    6   19
# 6    7   23
#    sid  purchase  age
# 0    1        10   10
# 1    1        20   10
# 2    2         2   22
# 3    2         3   22
# 4    3         1   11
# 5    4         2   21
# 6    5         4   55
#    sid  purchase   age
# 0    1      10.0  10.0
# 1    1      20.0  10.0
# 2    2       2.0  22.0
# 3    2       3.0  22.0
# 4    3       1.0  11.0
# 5    4       2.0  21.0
# 6    5       4.0  55.0
# 7    9      44.0   NaN
# 8    6       NaN  19.0
# 9    7       NaN  23.0
#    sid  purchase   age
# 0    1        10  10.0
# 1    1        20  10.0
# 2    2         2  22.0
# 3    2         3  22.0
# 4    3         1  11.0
# 5    4         2  21.0
# 6    5         4  55.0
# 7    9        44   NaN
#    sid  purchase  age
# 0    1      10.0   10
# 1    1      20.0   10
# 2    2       2.0   22
# 3    2       3.0   22
# 4    3       1.0   11
# 5    4       2.0   21
# 6    5       4.0   55
# 7    6       NaN   19
# 8    7       NaN   23

# %%
s1=pd.Series([1,2,3,4],index=[5,6,7,8,])
s2=pd.Series([1,2,3,4],index=[1,2,3,4])
s3=pd.Series([1,2,3,4,5,6],index=[6,6,5,5,7,8])
pd.concat([s1,s2], axis=1)
pd.concat([s3,s1], axis=1)
pd.concat([s3,s1], axis=1, join='inner')
# Out:
#      0    1
# 5  1.0  NaN
# 6  2.0  NaN
# 7  3.0  NaN
# 8  4.0  NaN
# 1  NaN  1.0
# 2  NaN  2.0
# 3  NaN  3.0
# 4  NaN  4.0
#    0  1
# 6  1  2
# 6  2  2
# 5  3  1
# 5  4  1
# 7  5  3
# 8  6  4
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_81433/2219097441.py:6: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   pd.concat([s3,s1], axis=1, join='inner')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_81433/2219097441.py in <module>
#       4 pd.concat([s1,s2], axis=1)
#       5 pd.concat([s3,s1], axis=1)
# ----> 6 pd.concat([s3,s1], axis=1, join='inner')
#       7
#       8
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     357     )
#     358
# --> 359     return op.get_result()
#     360
#     361
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     566
#     567                 index, columns = self.new_axes
# --> 568                 df = cons(data, index=index, copy=self.copy)
#     569                 df.columns = columns
#     570                 return df.__finalize__(self, method="concat")
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     635         elif isinstance(data, dict):
#     636             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 637             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     638         elif isinstance(data, ma.MaskedArray):
#     639             import numpy.ma.mrecords as mrecords
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     123
#     124         # don't force copy because getting jammed in an ndarray anyway
# --> 125         arrays = _homogenize(arrays, index, dtype)
#     126         # _homogenize ensures
#     127         #  - all(len(x) == len(index) for x in arrays)
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     605                 # Forces alignment. No need to copy data since we
#     606                 # are putting it into an ndarray later
# --> 607                 val = val.reindex(index, copy=False)
#     608
#     609             val = val._values
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, *args, **kwargs)
#    4667                 )
#    4668             kwargs.update({"index": index})
# -> 4669         return super().reindex(**kwargs)
#    4670
#    4671     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4972
#    4973         # perform the reindex on the axes
# -> 4974         return self._reindex_axes(
#    4975             axes, level, limit, tolerance, method, fill_value, copy
#    4976         ).__finalize__(self, method="reindex")
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4992
#    4993             axis = self._get_axis_number(a)
# -> 4994             obj = obj._reindex_with_indexers(
#    4995                 {axis: [new_index, indexer]},
#    4996                 fill_value=fill_value,
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5038
#    5039             # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5040             new_data = new_data.reindex_indexer(
#    5041                 index,
#    5042                 indexer,
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677         # some axes don't allow reindexing with dups
#     678         if not allow_dups:
# --> 679             self.axes[axis]._validate_can_reindex(indexer)
#     680
#     681         if axis >= self.ndim:
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    4105         # trying to reindex on an axis with duplicates
#    4106         if not self._index_as_unique and len(indexer):
# -> 4107             raise ValueError("cannot reindex on an axis with duplicate labels")
#    4108
#    4109     def reindex(
#
# ValueError: cannot reindex on an axis with duplicate labels
