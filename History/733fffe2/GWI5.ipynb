# %%
from ds_preamble import *

# %%
df = pd.read_csv('mdata.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66836 entries, 0 to 66835
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   contract_no     66836 non-null  int64
#  1   ins_idn         66836 non-null  int64
#  2   age_5           66836 non-null  int64
#  3   gender          66836 non-null  object
#  4   is_smoker       66836 non-null  int64
#  5   weight          64237 non-null  object
#  6   height          64813 non-null  object
#  7   occ_life_cover  65910 non-null  object
#  8   g_self_v1       66135 non-null  float64
#  9   g_self_v2       66130 non-null  float64
#  10  g_self_v3       66068 non-null  float64
#  11  g_self_v4       66085 non-null  float64
#  12  g_self_v5       66135 non-null  float64
#  13  g_self_v6       66102 non-null  float64
#  14  g_self_v7       66130 non-null  float64
#  15  g_self_v8       66150 non-null  float64
#  16  m_exam_v1_i     9249 non-null   float64
#  17  m_exam_v2_i     9238 non-null   float64
#  18  m_exam_v3_i     9243 non-null   float64
#  19  m_exam_v4_i     9266 non-null   float64
#  20  m_exam_v5_i     9239 non-null   float64
#  21  m_exam_v6_i     9254 non-null   float64
#  22  m_exam_v9_cm    9248 non-null   float64
#  23  m_exam_v10_cm   9237 non-null   float64
#  24  m_exam_v7_1     9236 non-null   float64
#  25  m_exam_v7_2     4627 non-null   float64
#  26  m_exam_v7_3     2357 non-null   float64
#  27  m_exam_v8_1     9249 non-null   float64
#  28  m_exam_v8_2     4628 non-null   float64
#  29  m_exam_v8_3     2362 non-null   float64
#  30  decision        66836 non-null  object
# dtypes: float64(22), int64(4), object(5)
# memory usage: 15.8+ MB

# %%
df.decision.value_counts()
# Out:
# std        57479
# substd      6015
# decline     3342
# Name: decision, dtype: int64

# %%
df.isna().mean().sort_values(ascending=False)[lambda x: x>0]
# Out:
# m_exam_v7_3       0.964735
# m_exam_v8_3       0.964660
# m_exam_v7_2       0.930771
# m_exam_v8_2       0.930756
# m_exam_v7_1       0.861811
# m_exam_v10_cm     0.861796
# m_exam_v2_i       0.861781
# m_exam_v5_i       0.861766
# m_exam_v3_i       0.861706
# m_exam_v9_cm      0.861631
# m_exam_v8_1       0.861616
# m_exam_v1_i       0.861616
# m_exam_v6_i       0.861542
# m_exam_v4_i       0.861362
# weight            0.038886
# height            0.030268
# occ_life_cover    0.013855
# g_self_v3         0.011491
# g_self_v4         0.011236
# g_self_v6         0.010982
# g_self_v7         0.010563
# g_self_v2         0.010563
# g_self_v5         0.010488
# g_self_v1         0.010488
# g_self_v8         0.010264
# dtype: float64

# %%
# df.weight.str.extract('(\d*\.?\d*)')
df.weight.str.contains('lb|lbs', case=False)
# Out:
#             0
# 0       160.6
# 1        64.4
# 2        58.1
# 3        56.6
# 4        69.9
# ...       ...
# 66831  139.48
# 66832  147.84
# 66833   119.9
# 66834  143.22
# 66835  132.66
#
# [66836 rows x 1 columns]

# %%
# df.height.str.extract('(\d*\.?\d*)')
df.height[2]
df.height.str.extract(r'([a-zA-Z])')
df.height.str.extract('([a-z])')
# df.height
# Out:
# nan
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 66831  NaN
# 66832  NaN
# 66833  NaN
# 66834  NaN
# 66835  NaN
#
# [66836 rows x 1 columns]
#          0
# 0        m
# 1        c
# 2      NaN
# 3        m
# 4        n
# ...    ...
# 66831  NaN
# 66832    c
# 66833  NaN
# 66834    n
# 66835    n
#
# [66836 rows x 1 columns]

# %%
# df.weight.str.extract('(\d+)')

# res = []
# for s in df.weight:

# d1 = df.weight.str.extract('(\d+)').astype('float').iloc[:,0]
d1 = df.weight.str.extract('(^\d*)').astype('float').iloc[:,0]
d2 = df.weight.str.contains('lb|lbs', case=False)
np.where(d2, d1*0.453592, d1)
df.weight=np.where(d2, d1*0.453592, d1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_53864/1629426272.py in <module>
#       5
#       6 # d1 = df.weight.str.extract('(\d+)').astype('float').iloc[:,0]
# ----> 7 d1 = df.weight.str.extract('(^\d*)').astype('float').iloc[:,0]
#       8 d2 = df.weight.str.contains('lb|lbs', case=False)
#       9 np.where(d2, d1*0.453592, d1)
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/miniforge3/envs/data_science/lib/python3.9/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
# d1 = df.weight.str.extract('(^\d*)').astype('float').iloc[:,0]
# d2 = df.weight.str.contains('lb|lbs', case=False)
# np.where(d2, d1*0.453592, d1)
# df.weight=np.where(d2, d1*0.453592, d1)
# in, cm, m, 

df.height.sample(50)
# df.weight.isna().sum()
# Out:
# 44426    64.57 In
# 39859     148.1CM
# 43389        1.7 M
# 48875     68.54In
# 14184    172.9 cm
# 60919     66.65 IN
# 45258      168.1cm
# 32756       1.74m
# 53209     168.1cm
# 51522     149.5Cm
# 23960     159.3Cm
# 10011       1.57M
# 8768          1.7m
# 52424       1.57 m
# 63399        1.63m
# 64054     71.26in
# 38062     164.7 CM
# 32739      56.85IN
# 22896     152.8CM
# 3186      165.7cm
# 30648      156.6cm
# 49047       1.52 m
# 37847       171 cm
# 56512     166.6Cm
# 48307        1.53m
# 466        72.44IN
# 17653       1.7 m
# 34592        1.52m
# 42621      62.68in
# 31463    162.2 Cm
# 19338    68.58 In
# 27695      1.57 m
# 54604      62.2IN
# 19221      68.5 in
# 911      167.9 Cm
# 3754      65.12IN
# 27165     163.4 CM
# 38668       1.41 M
# 40870     168.4 cm
# 12268    68.46 in
# 41416      166.1CM
# 29052     61.54IN
# 49800     62.44in
# 16337      69.72IN
# 48242          NaN
# 44627          NaN
# 34708        168cm
# 32607     175.4 cm
# 21811    165.3 cm
# 18116      1.66 m
# Name: height, dtype: object

# %%
cols = [col for col in df if col.startswith('g_self_')]
df[cols] = df[cols].fillna(0)
# df.filter(regex='^g_self_', axis = 1).fillna(0)
# df.iloc[:, df.columns.str.startswith('g_self_')]

# %%
cols = [col for col in df if col.startswith('m_exam_') and col.endswith('_i')]
df[cols] = df[cols].fillna('unk')
# df.filter(regex='^m_exam_.*_i', axis = 1)
# Out:
# m_exam_v1_i    0
# m_exam_v2_i    0
# m_exam_v3_i    0
# m_exam_v4_i    0
# m_exam_v5_i    0
# m_exam_v6_i    0
# dtype: int64

# %%
df.occ_life_cover = df.occ_life_cover.fillna('STD')

# %%
# df.groupby(['gender','age_5']).weight.median()
df.groupby(['gender','age_5'])['weight','m_exam_v9_cm' , 'm_exam_v10_cm', 'm_exam_v7_1', 'm_exam_v8_1'].transform('median')
# Out:
# /var/folders/c2/yj8ksjmn34v5f9csr1s82d8r0000gn/T/ipykernel_53864/3344468242.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['gender','age_5'])['weight','m_exam_v9_cm' , 'm_exam_v10_cm', 'm_exam_v7_1', 'm_exam_v8_1'].transform('median')
#           weight  m_exam_v9_cm  m_exam_v10_cm  m_exam_v7_1  m_exam_v8_1
# 0      65.000000        91.200         86.685      115.905       73.605
# 1      68.945984        90.740         86.940      115.370       73.510
# 2      54.000000        91.370         86.730      115.210       73.370
# 3      56.000000        91.350         86.420      115.780       73.680
# 4      57.000000        91.550         86.410      116.210       73.595
# ...          ...           ...            ...          ...          ...
# 66831  68.000000        91.605         86.295      115.550       73.775
# 66832  67.000000        91.405         86.760      116.515       73.225
# 66833  67.000000        91.405         86.760      116.515       73.225
# 66834  68.945984        90.740         86.940      115.370       73.510
# 66835  56.000000        91.350         86.420      115.780       73.680
#
# [66836 rows x 5 columns]
