# %% [markdown]
#  - SEHH3164 Assignment 1
#  - There are three programming questions. Answer all of them.
#  - Submit this file to Moodle.

# %%
# Import necessary packages. Do not modify. 
# Note: you CANNOT import any other packages.
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  # Redeeming gifts
#  - Suppose every time you go to 7-11 (the convenience store) to buy things, you'll be given a kind of stamp randomly, and that there are in total `n_stamps` kinds of stamps. Now, suppose that a collection of one stamp for each kind of stamp can be used to exchange for a gift. What is the probability that you can exchange a gift by making `n_purchases` purchases at 7-11?
#  - Your task is to estimate the probability by repeating the whole process many times, and records how many times you are able to exchange for a gift. Finally, return the fraction of times you can exchange a gift.
#  - Write a function to estimate the probability for the given values of `n_stamps` and `n_purchases`. Your function returns the estimated probability as output
#  - Then, draw a graph to show how the probability varies when `n_stamps` varies. The graph varies `n_stamps` while keeping `n_purchases` at 15.
#  - NOTE: you should repeat the processes for each estimation at least 10^4 times.
#  - NOTE: you may define other functions.

# %%
np.random.seed(1) # used to fix the random results. Do not modify

def stamp_prob(n_stamps, n_purchases, n_trials):
	pass


n_stamps, n_purchases, n_trials = 5, 10, 10**4

print(stamp_prob(n_stamps, n_purchases, n_trials)) # example usage. The output is omitted
# Out:
# None

# %% [markdown]
#  # event insertion
#  - you are given the start time and end time of a number of events, and the events are non-overlapping. Specifically, you are given a list `events`, such that `events[i] =[start_i, end_i]` represents the start and end time of the `ith` event.
#  - you are also given a new event `new_event`. You task is to insert `new_event` into `events`, and return the updated `events` in ascending sorted order, according to the start time of the events. You need to make sure `events` still does not have any overlapping. You can merge overlapping events into one single event if necessary.
#  - return `events` at the end as output

# %%
def insert_event(events, new_event):
	pass

# examples
events, new_event = [[1,3],[6,9]], [2,5]
print(insert_event(events, new_event)) # [[1,5],[6,9]]

events, new_event = [[3,5], [1,2],[6,7],[12,16],[8,10]], [4,8]
print(insert_event(events, new_event)) # [[1,2],[3,10],[12,16]]. Note: event [4,8] overlaps with [3,5],[6,7],[8,10]

events, new_event = [[1,5]], [2,4]
print(insert_event(events, new_event)) # [[1,5]]

events, new_event = [[1,10]], [2,14]
print(insert_event(events, new_event)) # [[1,14]]
# Out:
# None
# None
# None
# None

# %% [markdown]
#  # items appearing in at least $k$ of the given lists
#  - Complete the function `appear_at_least_k` below. This function accepts a tuple `t` of lists. Each list contains some real numbers. The function then returns another list, which contains those numbers that appear in at least `k` of the lists of the tuple `t` , where `k` is another parameter given by the user to the function. Note that `k` must be a positive integer. Refer to the code below for more information.

# %%
def appear_at_least_k(t, k):
	pass


a1=[1,2,3,4]
a2=[1,2,3,5,5,6]
a3=[1,7,7,7]
print(appear_at_least_k((a1,a2,a3),1)) # [1, 2, 3, 4, 5, 6, 7]
print(appear_at_least_k((a1,a2,a3),2)) # [1, 2, 3]
print(appear_at_least_k((a1,a2,a3),3)) # [1]
print(appear_at_least_k((a1,a2,a3),4)) # []
# Out:
# None
# None
# None
# None
